# %% [markdown]
# ## Cálculos de medidas de Posição acerca de preços unitários de pontos de função com objetivo similar ao contrato 014/2024/SEPLAG, para análise de dados.

# %%
# Importda função para Cálculo da Moda
from statistics import mode

# %%
# Dados
dadosModa = [601.33, 638.41, 558.61, 943.26, 585.21, 1060.00, 650.00, 555.00]

# %%
# Calculando a moda
mode(dadosModa)
# Out:
# 601.33

# %%
# Impor tda função para Cálculo da Median
from statistics import median

# %%
# Dados
dadosMediana = [601.33, 638.41, 558.61, 943.26, 585.21, 1060.00, 650.00, 555.00]

# %%
# Calculando a mediana
median(dadosMediana)
# Out:
# 619.87

# %%
# Import da função para Cálculo da Média
from statistics import mean

# %%
# Dados
dadosMedia = [601.33, 638.41, 558.61, 943.26, 585.21, 1060.00, 650.00, 555.00]

# %%
# Calculando a média
mean(dadosMedia)
# Out:
# 698.9775
